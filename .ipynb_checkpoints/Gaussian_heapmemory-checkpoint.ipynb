# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import IsolationForest

# %%
PATH =   r"training/"
PATHTest =   r"testing/"

rawdata = pd.read_csv(PATHTest+"part-067.csv")
splitData = train_test_split(rawdata, test_size= 0.3)
rng = np.random.RandomState(42)
train = splitData[0]
test = splitData[1]
most_important_names= ['Heap usage activity : (d/dx (MXBean(java.lang:type=Memory).HeapMemoryUsage.used))']

# %%
sc = StandardScaler()
X_train = sc.fit_transform(df.drop(["host", "process", "timestamp", "isAnomaly"], axis="columns"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0d80f298f599> in <module>
# ----> 1 sc = StandardScaler()
#       2 X_train = sc.fit_transform(df.drop(["host", "process", "timestamp", "isAnomaly"], axis="columns"))
#
# NameError: name 'StandardScaler' is not defined

# %%
normal = rawdata.loc[rawdata['isAnomaly'] == False, 'Heap usage activity : (d/dx (MXBean(java.lang:type=Memory).HeapMemoryUsage.used))']
anomaly = rawdata.loc[rawdata['isAnomaly'] == True, 'Heap usage activity : (d/dx (MXBean(java.lang:type=Memory).HeapMemoryUsage.used))']

# %%
expected = np.where(test['isAnomaly'] == True, -1, 1)

# %%
fig, axs = plt.subplots(1,2)
normal.hist(ax=axs[0],bins=10)
anomaly.hist(ax=axs[1],bins=10, color='red')

# %%
# fig, ax = plt.subplots()
# a = rawdata.loc[rawdata['isAnomaly'] == True, ('timestamp', 'Heap usage activity : (d/dx (MXBean(java.lang:type=Memory).HeapMemoryUsage.used))')] #anomaly

# # ax.plot(rawdata['timestamp'], rawdata['Heap usage activity : (d/dx (MXBean(java.lang:type=Memory).HeapMemoryUsage.used))'], color='blue')
# # ax.scatter(a['timestamp'],a['Heap usage activity : (d/dx (MXBean(java.lang:type=Memory).HeapMemoryUsage.used))'], color='red')

# rawdata.plot(kind='line',x='timestamp',y='Heap usage activity : (d/dx (MXBean(java.lang:type=Memory).HeapMemoryUsage.used))',color='red')

# %%
sns.set_style("darkgrid")
rd = rawdata[['timestamp', 'Heap usage activity : (d/dx (MXBean(java.lang:type=Memory).HeapMemoryUsage.used))']].to_numpy()
plt.plot(rd[:,0], rd[:,1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-c49ca947d6b1> in <module>
#       2 rd = rawdata[['timestamp', 'Heap usage activity : (d/dx (MXBean(java.lang:type=Memory).HeapMemoryUsage.used))']].to_numpy()
#       3 plt.plot(rd[:,0], rd[:,1])
# ----> 4 plt.show()
#
# d:\academics\software\python\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# d:\academics\software\python\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# d:\academics\software\python\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# d:\academics\software\python\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <d:\academics\software\python\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# d:\academics\software\python\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# d:\academics\software\python\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# d:\academics\software\python\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# d:\academics\software\python\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# d:\academics\software\python\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# d:\academics\software\python\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# d:\academics\software\python\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# d:\academics\software\python\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# d:\academics\software\python\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# d:\academics\software\python\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# d:\academics\software\python\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# d:\academics\software\python\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2605                 artists.remove(spine)
#    2606
# -> 2607         self._update_title_position(renderer)
#    2608
#    2609         if not self.axison or inframe:
#
# d:\academics\software\python\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2547                     if (ax.xaxis.get_label_position() == 'top' or
#    2548                             ax.xaxis.get_ticks_position() in choices):
# -> 2549                         bb = ax.xaxis.get_tightbbox(renderer)
#    2550                     else:
#    2551                         bb = ax.get_window_extent(renderer)
#
# d:\academics\software\python\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1160             return
#    1161
# -> 1162         ticks_to_draw = self._update_ticks()
#    1163
#    1164         self._update_label_position(renderer)
#
# d:\academics\software\python\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1078         """
#    1079         major_locs = self.get_majorticklocs()
# -> 1080         major_labels = self.major.formatter.format_ticks(major_locs)
#    1081         major_ticks = self.get_major_ticks(len(major_locs))
#    1082         self.major.formatter.set_locs(major_locs)
#
# d:\academics\software\python\lib\site-packages\matplotlib\ticker.py in format_ticks(self, values)
#     257         """Return the tick labels for all the ticks at once."""
#     258         self.set_locs(values)
# --> 259         return [self(value, i) for i, value in enumerate(values)]
#     260
#     261     def format_data(self, value):
#
# d:\academics\software\python\lib\site-packages\matplotlib\ticker.py in <listcomp>(.0)
#     257         """Return the tick labels for all the ticks at once."""
#     258         self.set_locs(values)
# --> 259         return [self(value, i) for i, value in enumerate(values)]
#     260
#     261     def format_data(self, value):
#
# d:\academics\software\python\lib\site-packages\matplotlib\category.py in __call__(self, x, pos)
#     152             return ""
#     153         r_mapping = {v: StrCategoryFormatter._text(k)
# --> 154                      for k, v in self._units.items()}
#     155         return r_mapping.get(int(np.round(x)), '')
#     156
#
# d:\academics\software\python\lib\site-packages\matplotlib\category.py in <dictcomp>(.0)
#     152             return ""
#     153         r_mapping = {v: StrCategoryFormatter._text(k)
# --> 154                      for k, v in self._units.items()}
#     155         return r_mapping.get(int(np.round(x)), '')
#     156
#
# d:\academics\software\python\lib\site-packages\matplotlib\category.py in _text(value)
#     155         return r_mapping.get(int(np.round(x)), '')
#     156
# --> 157     @staticmethod
#     158     def _text(value):
#     159         """Converts text values into utf-8 or ascii strings.
#
# KeyboardInterrupt:
